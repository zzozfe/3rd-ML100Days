# %% [markdown]
# HW1

# %%
import numpy as np
import matplotlib.pyplot as pltm

# %%
def mean_squared_error(y,yp):
    mse = sum((y-yp)**2)/len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y,y_hat)
print(f'The Mean squared error is {MSE:3.2f}')
# Out:
# The Mean squared error is 229.86

# %% [markdown]
# ------------------------------------
# HW2

# %% [markdown]
# 1 : 我選的資料為chicago的測速照相機和闖紅燈照相機所記錄的資料
#     透過這筆資料能夠知道事件發生在何時何地從甚麼方向來等等
#     並且可以瞭解chicago的交通狀況並去改善
#
# 2 : 資料來自chicago所設立的開源資料網站 是統計這個城市的資料的網站
#
# 3 : 資料是以CSV檔所儲存 其中有字串和整數型態
#
# 4 : 其應該是想解決交通違法的狀況 可以觀察裝設照相機後違法狀況是否減少、是否有累犯發生

# %% [markdown]
# HW3
# 目標 : 提升業績(營業額) --> 提升載客量 or 降低成本
# 資料 : 地區性的人口資料 --> 可透過政府開放資料網站取得csv檔
#        觀光局的景點人流量 --> 可透過觀光局網站取得
#        市場競爭者數量 --> 可透過政府公告所登記的數量來取得
# 評估 : 給定公司的成本限制下要求最大利潤 --> max pi s.t c = c_bar

# %%
HW3 目標 : 提升業績(營業額) --> 提升載客量 or 降低成本 資料 : 地區性的人口資料 --> 可透過政府開放資料網站取得csv檔 觀光局的景點人流量 --> 可透過觀光局網站取得 市場競爭者數量 --> 可透過政府公告所登記的數量來取得 評估 : 給定公司的成本限制下要求最大利潤 --> max pi s.t c = c_bar
